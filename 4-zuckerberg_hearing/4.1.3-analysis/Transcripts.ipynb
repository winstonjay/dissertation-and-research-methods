# %%
# %matplotlib inline
import collections

# --- third party modules. ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')

# local functions
import plotting
from topicmodel import TopicModel

# load 100% of data and shuffle
df = pd.read_csv('data/transcripts.csv').sample(frac=1)
df['role']    = df.name.apply(lambda a: 'WITNESS' if a == 'ZUCKERBERG' else 'CONGRESS')
df['words']   = df.text.apply(lambda a: len(a.split()))
df['cleaned'] = df.text.apply(plotting.clean_text)
df.head()
# Out:
#             name                         longname  \
# 1326    MCNERNEY         REP. MCNERNEY (D-CALIF.)
# 874      PALLONE  REP. FRANK PALLONE JR. (D-N.J.)
# 807      GARDNER                          GARDNER
# 1414  ZUCKERBERG                       ZUCKERBERG
# 1418  ZUCKERBERG                       ZUCKERBERG
#
#                                                    text      role  words  \
# 1326  I thank the Chairman. Mr. Zuckerberg, I — I th...  CONGRESS     95
# 874   And their justification that those protections...  CONGRESS    493
# 807   So, I — I — I — and I think that goes to the h...  CONGRESS    101
# 1414  Congressman, I do not off the top of my head, ...   WITNESS     21
# 1418  ... block that, so we need to know when someon...   WITNESS     18
#
#                                                 cleaned
# 1326  zuckerberg agre testifi hous senat committe lo...
# 874   justif protect need feder trade commiss contro...
# 807   heart expect consum user necessarili understan...
# 1414                                     head team back
# 1418                         block repeat access servic
